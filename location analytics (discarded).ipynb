# %%
import pandas as pd
df = pd.read_csv('all 2.csv')
df
# Out:
# /home/coris/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (14,16,17,19,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132519    22172                12         NaN               1
# 1      132531    22189                24         NaN               1
# 2      132539    22192                54         NaN               1
# 3      132697    22275                28         NaN               1
# 4      132760    22310                87         NaN               1
# ...       ...      ...               ...         ...             ...
# 43426  185924    48719                12         1.0               3
# 43427  185927    41939                12         4.0               3
# 43428  185930    36265                65         2.0               3
# ...

# %%
df['booking'] = df["online_booking"].astype(str) + df["mobile_site_booking"].astype(str)
df
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132519    22172                12         NaN               1
# 1      132531    22189                24         NaN               1
# 2      132539    22192                54         NaN               1
# 3      132697    22275                28         NaN               1
# 4      132760    22310                87         NaN               1
# ...       ...      ...               ...         ...             ...
# 43426  185924    48719                12         1.0               3
# 43427  185927    41939                12         4.0               3
# 43428  185930    36265                65         2.0               3
# 43429  185935    48726                12         2.0               3
# 43430  185939    48729                12         1.0               3
#
#        from_area_id  to_area_id  from_city_id  to_city_id  \
# 0               NaN         NaN            15       108.0
# ...

# %%
df.loc[df.booking == "Onlinenan", "books"] = "Online"
df.loc[df.booking == "nanMobile", "books"] = "Mobile"
df
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132519    22172                12         NaN               1
# 1      132531    22189                24         NaN               1
# 2      132539    22192                54         NaN               1
# 3      132697    22275                28         NaN               1
# 4      132760    22310                87         NaN               1
# ...       ...      ...               ...         ...             ...
# 43426  185924    48719                12         1.0               3
# 43427  185927    41939                12         4.0               3
# 43428  185930    36265                65         2.0               3
# 43429  185935    48726                12         2.0               3
# 43430  185939    48729                12         1.0               3
#
#        from_area_id  to_area_id  from_city_id  to_city_id  \
# 0               NaN         NaN            15       108.0
# ...

# %%
df.books.value_counts()
# Out:
# Online    15270
# Mobile     1878
# Name: books, dtype: int64

# %%
df.to_csv('all.csv', index = False)

# %%
df1 = df[df['user_id']== 21413]
df1
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 1  132513    21413                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id      from_date to_date  \
# 1        1010.0       540.0           NaN         NaN  1/1/2013 9:00     NaN
#
#    online_booking  mobile_site_booking booking_created  from_lat  from_long  \
# 1               0                    0   1/1/2013 2:25  12.96691   77.74935
#
#      to_lat   to_long  Car_Cancellation
# 1  12.92768  77.62664                 0

# %%
df2 = df.drop_duplicates(subset = "user_id",keep = False, inplace = False)
len(df2['user_id'].value_counts())
users2 = df2['user_id'].unique()

# %%
df['user_id'].isin(users2).sum()
# Out:
# 15935

# %%
l3 = [x for x in users if x not in users2]
len(l3)
# Out:
# 6332

# %%
df_um = df[pd.DataFrame(df.user_id.tolist()).isin(l3).any(1).values]
df_um
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 5      132518    17712                12         NaN               2
# 11     132524    17037                12         NaN               2
# 14     132527       16                28         NaN               2
# 15     132528    15097                12         NaN               2
# 16     132530      761                12         NaN               2
# ...       ...      ...               ...         ...             ...
# 43419  185929    46807                12         NaN               2
# 43420  185930    36265                65         2.0               3
# 43425  185936    30220                12         NaN               2
# 43426  185937    14364                12         NaN               2
# 43429  185940    30724                87         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# user_id                    0
# vehicle_model_id           0
# package_id             35881
# travel_type_id             0
# from_area_id              88
# to_area_id              9138
# from_city_id           27086
# to_city_id             41843
# from_date                  0
# to_date                17890
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                  93
# from_long                 93
# to_lat                  9138
# to_long                 9138
# Car_Cancellation           0
# dtype: int64

# %%
df.Car_Cancellation.value_counts()
# Out:
# 0    40299
# 1     3132
# Name: Car_Cancellation, dtype: int64

# %%
df_cancelled = df[df['from_city_id'].isna()]

# %%
df_cancelled.isna().sum()
# Out:
# id                         0
# user_id                    0
# vehicle_model_id           0
# package_id             19984
# travel_type_id             0
# from_area_id               0
# to_area_id              7298
# from_city_id           27086
# to_city_id             26890
# from_date                  0
# to_date                17809
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                   0
# from_long                  0
# to_lat                  7298
# to_long                 7298
# Car_Cancellation           0
# dtype: int64

# %%
len(df_cancelled)
# Out:
# 27086

# %%
df_cancelled['to_city_id'].value_counts()
# Out:
# 32.0     65
# 55.0     30
# 146.0    15
# 29.0     10
# 147.0     7
# 108.0     5
# 131.0     4
# 113.0     3
# 126.0     3
# 49.0      3
# 121.0     2
# 44.0      2
# 13.0      2
# 31.0      2
# 64.0      2
# 41.0      2
# 65.0      2
# 56.0      2
# 61.0      2
# 170.0     1
# 161.0     1
# 132.0     1
# 115.0     1
# 45.0      1
# 160.0     1
# 66.0      1
# 97.0      1
# 149.0     1
# 12.0      1
# 62.0      1
# 154.0     1
# 80.0      1
# 176.0     1
# 58.0      1
# 134.0     1
# 8.0       1
# 36.0      1
# 76.0      1
# 163.0     1
# 192.0     1
# 168.0     1
# 110.0     1
# 119.0     1
# 17.0      1
# 89.0      1
# 24.0      1
# 135.0     1
# 152.0     1
# 125.0     1
# 144.0     1
# 85.0      1
# 189.0     1
# Name: to_city_id, dtype: int64

# %%
df[df['from_city_id'] == 15.0]
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 6      132519    22172                12         NaN               1
# 24     132539    22192                54         NaN               1
# 233    132780    22318                65         NaN               1
# 243    132791    22323                65         NaN               1
# 328    132907    22385                12         NaN               1
# ...       ...      ...               ...         ...             ...
# 43426  185937    14364                12         NaN               2
# 43427  185938    48727                12         NaN               2
# 43428  185939    48729                12         1.0               3
# 43429  185940    30724                87         NaN               2
# 43430  185941    48730                12         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
df_round = df.round(decimals=0)

# %%
df_round.to_city_id.value_counts()
# Out:
# 32.0     475
# 55.0     174
# 29.0     116
# 146.0     89
# 108.0     64
#         ...
# 120.0      1
# 50.0       1
# 179.0      1
# 165.0      1
# 197.0      1
# Name: to_city_id, Length: 116, dtype: int64

# %%
df['from_city_id'].value_counts()
# Out:
# 15.0    16233
# 1.0       106
# 31.0        6
# Name: from_city_id, dtype: int64

# %%
df_package = df[df['travel_type_id']== 3]

# %%
df_package.travel_type_id.value_counts()
# Out:
# 3    7550
# Name: travel_type_id, dtype: int64

# %%
df_package
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 8      132521    22182                65         2.0               3
# 20     132535    22190                87         2.0               3
# 23     132538    21995                12         1.0               3
# 34     132552    22201                12         1.0               3
# 47     132569    15846                12         2.0               3
# ...       ...      ...               ...         ...             ...
# 43415  185924    48719                12         1.0               3
# 43417  185927    41939                12         4.0               3
# 43420  185930    36265                65         2.0               3
# 43424  185935    48726                12         2.0               3
# 43428  185939    48729                12         1.0               3
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
df.package_id.value_counts()
# Out:
# 1.0    3503
# 2.0    2651
# 6.0     502
# 4.0     412
# 3.0     375
# 7.0     101
# 5.0       6
# Name: package_id, dtype: int64
